# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# Requirement already satisfied: numpy>=2.3.3 in /opt/homebrew/Cellar/jupyterlab/4.5.8_1/libexec/lib/python3.14/site-packages (from pandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Cellar/jupyterlab/4.5.8_1/libexec/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.5.8_1/libexec/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp314-cp314-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 3.4 MB/s  0:00:03m 3.2 MB/s eta 0:00:01
# Installing collected packages: pandas
# Successfully installed pandas-3.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# Create the DataFrame
df = pd.DataFrame({
    "Name": ["Rahul", "Priya", "Amit", "Anuj"],
    "Age": [25, 30, 28, 35],
    "Department": ["HR", "IT", "Finance", "IT"],
    "Salary": [30000, 50000, 45000, 60000]
})

print("DataFrame:")
print(df)
# Out:
# DataFrame:
#     Name  Age Department  Salary
# 0  Rahul   25         HR   30000
# 1  Priya   30         IT   50000
# 2   Amit   28    Finance   45000
# 3   Anuj   35         IT   60000

# %%
# 1. Show first 2 rows
print("\nFirst 2 rows:")
print(df.head(2))
# Out:
# First 2 rows:
#     Name  Age Department  Salary
# 0  Rahul   25         HR   30000
# 1  Priya   30         IT   50000

# %%
# 2. Show summary statistics
print("\nSummary statistics:")
print(df.describe())
# Out:
# Summary statistics:
#              Age   Salary
# count   4.000000      4.0
# mean   29.500000  46250.0
# std     4.203173  12500.0
# min    25.000000  30000.0
# 25%    27.250000  41250.0
# 50%    29.000000  47500.0
# 75%    31.250000  52500.0
# max    35.000000  60000.0

# %%
# 3. Display only IT employees
print("\nIT employees:")
print(df[df["Department"] == "IT"])
# Out:
# IT employees:
#     Name  Age Department  Salary
# 1  Priya   30         IT   50000
# 3   Anuj   35         IT   60000

# %%
# 4. Add new column: Bonus = Salary * 0.10
df["Bonus"] = df["Salary"] * 0.10

print("\nDataFrame with Bonus column:")
print(df)
# Out:
# DataFrame with Bonus column:
#     Name  Age Department  Salary   Bonus
# 0  Rahul   25         HR   30000  3000.0
# 1  Priya   30         IT   50000  5000.0
# 2   Amit   28    Finance   45000  4500.0
# 3   Anuj   35         IT   60000  6000.0
